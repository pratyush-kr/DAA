# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
def linearplot(X, y):
    regressor = LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=1)
    regressor = LinearRegression()
    regressor.fit(X_train, y_train)
    return regressor, X_test, y_test

# %%
def polyplot(X, y):
    regressor = LinearRegression()
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)
    poly_reg = PolynomialFeatures(degree=2)
    X_poly = poly_reg.fit_transform(X)
    regressor = LinearRegression()
    regressor.fit(X_poly, y)
    return regressor, X_test, y_test

# %%
dataset = pd.read_csv('new.csv')

# %% [markdown]
# DAC_MAX (1, 2)

# %%
X_DAC_MAX = dataset.iloc[:, 0].values
y_DAC_MAX = dataset.iloc[:, 1].values
X_DAC_MAX = X_DAC_MAX.reshape(len(X_DAC_MAX), 1)

# %% [markdown]
# DAC_MIN (3, 4)

# %%
X_DAC_MIN = dataset.iloc[:, 2].values
y_DAC_MIN = dataset.iloc[:, 3].values
X_DAC_MIN = X_DAC_MIN.reshape(len(X_DAC_MIN), 1)

# %% [markdown]
# MAX(5, 6)

# %%
X_MAX = dataset.iloc[:, 4].values
y_MAX = dataset.iloc[:, 5].values
X_MAX = X_MAX.reshape(len(X_MAX), 1)

# %% [markdown]
# MIN(7, 8)

# %%
X_MIN = dataset.iloc[:, 6].values
y_MIN = dataset.iloc[:, 7].values
X_MIN = X_MIN.reshape(len(X_MIN), 1)

# %% [markdown]
# BRUTE_MAX(9, 10)

# %%
X_BMAX = dataset.iloc[:, 8].values
y_BMAX = dataset.iloc[:, 9].values
X_BMAX = X_BMAX.reshape(len(X_BMAX), 1)

# %% [markdown]
# BRUTE_MIN(11, 12)

# %%
X_BMIN = dataset.iloc[:, 10].values
y_BMIN = dataset.iloc[:, 11].values
X_BMIN = X_BMIN.reshape(len(X_BMIN), 1)

# %%
regressor, X, y = linearplot(X_DAC_MAX, y_DAC_MAX)
plt.scatter(X, y, label = 'DAC_MAX', color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.xlabel('N')
plt.ylabel('Complexity')
plt.title('N vs Complexity (DAC MAX)')
plt.legend()
plt.show()

# %%
regressor, X, y = linearplot(X_DAC_MIN, y_DAC_MIN)
plt.scatter(X, y, label = 'DAC_MIN', color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.xlabel('N')
plt.ylabel('Complexity')
plt.title('N vs Complexity (DAC MIN)')
plt.legend()
plt.show()

# %%
regressor, X, y = linearplot(X_MAX, y_MAX)
plt.scatter(X, y, label = 'MAX', color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.xlabel('N')
plt.ylabel('Complexity')
plt.title('N vs Complexity (MAX)')
plt.legend()
plt.show()

# %%
regressor, X, y = linearplot(X_MIN, y_MIN)
plt.scatter(X, y, label = 'MIN', color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.xlabel('N')
plt.ylabel('Complexity')
plt.title('N vs Complexity (MIN)')
plt.legend()
plt.show()

# %%
regressor, X, y = polyplot(X_BMAX, y_BMAX)
poly_reg = PolynomialFeatures(degree=2)
plt.scatter(X, y, label = 'MAX', color = 'red')
plt.plot(X, regressor.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.xlabel('N')
plt.ylabel('Complexity')
plt.title('N vs Complexity (MAX)')
plt.legend()
plt.show()
