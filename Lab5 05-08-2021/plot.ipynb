# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %%
dataset = pd.read_csv('Data.csv')

# %%
from natsort import index_natsorted
dataset = dataset.sort_values(
   by="N",
   key=lambda x: np.argsort(index_natsorted(dataset["N"]))
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-eff9fa724667> in <module>
#       1 from natsort import index_natsorted
# ----> 2 dataset = dataset.sort_values(
#       3    by="N",
#       4    key=lambda x: np.argsort(index_natsorted(dataset["n"]))
#       5 )
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6263                 ascending = ascending[0]
#    6264
# -> 6265             indexer = nargsort(
#    6266                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6267             )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position, key, mask)
#     371
#     372     if key is not None:
# --> 373         items = ensure_key_mapped(items, key)
#     374         return nargsort(
#     375             items,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/sorting.py in ensure_key_mapped(values, key, levels)
#     529         return _ensure_key_mapped_multiindex(values, key, level=levels)
#     530
# --> 531     result = key(values.copy())
#     532     if len(result) != len(values):
#     533         raise ValueError(
#
# <ipython-input-3-eff9fa724667> in <lambda>(x)
#       2 dataset = dataset.sort_values(
#       3    by="N",
# ----> 4    key=lambda x: np.argsort(index_natsorted(dataset["n"]))
#       5 )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'n'

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
plt.scatter(X, y, color='red')
plt.xlabel('n ->')
plt.ylabel('frequency ->')
plt.title('n vs frequency(Heap Sort)')
plt.show()
